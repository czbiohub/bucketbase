# %%
import pandas as pd

# %%
single_file=pd.read_csv(
    '/Users/parker.bremer/coding_projects/bucketbase/data/individual_sample_data_subset/unzipped/BRYU005_Bacterial_Supernatant/pos/BRYU005_Pos_SA0059_QE2_HILIC_064.txt',
    sep='\t',
    index_col=0
)

# %%
single_file
# Out:
#                                            Title  Scans  RT left(min)  \
# PeakID
# 0                                        Unknown    218      0.931734
# 1                                        Unknown    219      0.927177
# 2                             w/o MS2:Morpholine    219      0.921664
# 3                   w/o MS2:1,2-Diethylhydrazine    219      0.921664
# 4                        w/o MS2:Cyclohexylamine    219      0.921664
# ...                                          ...    ...           ...
# 1559    w/o MS2:Scopolamine .beta.-D-glucuronide   4394      9.639092
# 1560                  w/o MS2:Masitinib (AB1010)   4404      9.761224
# 1561    w/o MS2:L-Cysteine-glutathione disulfide   4419      9.855825
# 1562                    w/o MS2:Terbufos sulfone   4429      9.962312
# 1563                                     Unknown   4669     10.443970
#
#          RT (min)  RT right (min)  Precursor m/z       Height          Area  \
# PeakID
# ...

# %%
single_file.columns
# Out:
# Index(['Title', 'Scans', 'RT left(min)', 'RT (min)', 'RT right (min)',
#        'Precursor m/z', 'Height', 'Area', 'Model masses', 'Adduct', 'Isotope',
#        'Comment', 'Reference RT', 'Reference m/z', 'Formula', 'Ontology',
#        'InChIKey', 'SMILES', 'Annotation tag (VS1.0)', 'RT matched',
#        'm/z matched', 'MS/MS matched', 'RT similarity', 'Dot product',
#        'Reverse dot product', 'Fragment presence %', 'Total score', 'S/N',
#        'MS1 isotopes', 'MSMS spectrum'],
#       dtype='object')

# %%
single_file.loc[
    (~single_file['MSMS spectrum'].isna()) &
    (single_file.Title == 'Unknown')
]
# Out:
#           Title  Scans  RT left(min)   RT (min)  RT right (min)  \
# PeakID
# 62      Unknown    229      0.912545   1.033634        1.127202
# 63      Unknown    229      0.917104   1.033634        1.117095
# 70      Unknown    229      0.889740   1.033634        1.169704
# 72      Unknown    229      0.885180   1.033634        1.169704
# 76      Unknown    229      0.889740   1.033634        1.117095
# ...         ...    ...           ...        ...             ...
# 1535    Unknown   4224      9.616810   9.651108        9.962312
# 1543    Unknown   4259      9.308154   9.736265       10.028820
# 1548    Unknown   4319      9.606671   9.894444        9.988235
# 1556    Unknown   4369      9.881342  10.028820       10.254210
# 1563    Unknown   4669     10.443970  10.831560       10.912130
#
#         Precursor m/z        Height        Area  Model masses    Adduct  ...  \
# PeakID                                                                   ...
# ...

# %%
single_file.loc[
    (~single_file['MSMS spectrum'].isna()) &
    (single_file.Title == 'Unknown')
]['Precursor m/z'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
single_file.loc[
    (~single_file['MSMS spectrum'].isna())
]
# Out:
#                                           Title  Scans  RT left(min)  \
# PeakID
# 41                           w/o MS2:Butylamine    224      0.806713
# 62                                      Unknown    229      0.912545
# 63                                      Unknown    229      0.917104
# 70                                      Unknown    229      0.889740
# 72                                      Unknown    229      0.885180
# ...                                         ...    ...           ...
# 1551    1H-Indole-6-ethanamine, .alpha.-methyl-   4344      9.920580
# 1552                                    Cystine   4349      9.881342
# 1556                                    Unknown   4369      9.881342
# 1558               w/o MS2:Disulfoton sulfoxide   4394      9.813957
# 1563                                    Unknown   4669     10.443970
#
#          RT (min)  RT right (min)  Precursor m/z        Height          Area  \
# PeakID
# ...

# %%
single_file.loc[
    (single_file['MS/MS matched'] == True) &
    (single_file.Title.str.contains("_d"))
][['Title','InChIKey']]
# Out:
#                        Title           InChIKey
# PeakID
# 453        1_HippuricAcid_d5  Internal Standard
# 551          1_Creatinine_d3  Internal Standard
# 597             1_Choline_d9  Internal Standard
# 637                1_TMAO_d9  Internal Standard
# 929     1_Acetylcarnitine_d3  Internal Standard
# 984          1_Methionine_d8  Internal Standard
# 1037          1_Carnitine_d3  Internal Standard
# 1291          1_Glutamine_d5  Internal Standard
# 1308             1_Serine_d3  Internal Standard
# 1350      1_Glutamic Acid_d3  Internal Standard
# 1508           1_Arginine_d7  Internal Standard

# %%
single_file.columns
# Out:
# Index(['Title', 'Scans', 'RT left(min)', 'RT (min)', 'RT right (min)',
#        'Precursor m/z', 'Height', 'Area', 'Model masses', 'Adduct', 'Isotope',
#        'Comment', 'Reference RT', 'Reference m/z', 'Formula', 'Ontology',
#        'InChIKey', 'SMILES', 'Annotation tag (VS1.0)', 'RT matched',
#        'm/z matched', 'MS/MS matched', 'RT similarity', 'Dot product',
#        'Reverse dot product', 'Fragment presence %', 'Total score', 'S/N',
#        'MS1 isotopes', 'MSMS spectrum'],
#       dtype='object')

# %%
single_file.loc[
    (single_file['MS/MS matched'] == False) &
    (single_file.Title.str.contains("_d"))
]['Title']
# Out:
# PeakID
# 445     w/o MS2:1_HippuricAcid_d5
# 1081          w/o MS2:1_Valine_d8
# 1120         w/o MS2:1_Alanine_d3
# 1486          w/o MS2:1_Serine_d3
# Name: Title, dtype: object
